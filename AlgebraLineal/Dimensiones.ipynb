# %% [markdown]
# <a href="https://colab.research.google.com/github/yazfir/Projects2021/blob/master/AlgebraLineal/Dimensiones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de pantalla de 2021-05-31 23-44-53.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
escalar = 5.679
vector = np.array([1,2,3])
matriz = np.array([[1,2],[3,4]])
tensor = np.array([
    [[1,2,3],[4,5,6],[6,7,8]],
    [[11,12,13],[14,15,16],[17,18,19]],
    [[21,22,23],[24,25,26],[27,28,29]],
])

escalar
# Out:
# 5.679

# %%
escalar.shape #La escalar no tiene este atributo y manda error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-f06d931aaba9> in <module>()
# ----> 1 escalar.shape
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
vector.shape # Te devuelve el tamaño y dimensión
# Out:
# (3,)

# %%
len(vector) # Te devuelve sólo el tamaño sin decir dimensión
# Out:
# 3

# %%
matriz.shape #(filas,columnas)
# Out:
# (2, 2)

# %%
len(matriz) # Nos devuelve la cantidad de elemento en la filas
# Out:
# 2

# %%
matriz.size # La cantidad de elementos dentro de la matriz
# Out:
# 4

# %%
tensor.shape #(fila, columna, dimensión)
# Out:
# (3, 3, 3)
